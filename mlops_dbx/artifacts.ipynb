# %%
username = dbutils.widgets.get("username")
if username=="" or username is None:
    raise Exception("Provide the username")

# %%
# %sql
CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_dev MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_dev/';
GRANT MANAGE, ALL PRIVILEGES ON CATALOG mlops_dbx_talk_dev TO `account users`;

CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_test MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_test/';
GRANT MANAGE, ALL PRIVILEGES ON CATALOG mlops_dbx_talk_test TO `account users`;

CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_staging MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_staging/';
GRANT MANAGE, ALL PRIVILEGES ON CATALOG mlops_dbx_talk_staging TO `account users`;

CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_prod MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_prod/';
GRANT MANAGE, ALL PRIVILEGES ON CATALOG mlops_dbx_talk_prod TO `account users`;

-- CREATE VOLUME IF NOT EXISTS mlops_dbx_talk_dev.churn.helpers;

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_dev.{username} MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_dev/'")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_test.{username} MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_test/'")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_staging.{username} MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_staging/'")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_prod.{username} MANAGED LOCATION 'abfss://mlops@stcapacitacionpostobon.dfs.core.windows.net/data/mlops_dbx_talk_prod/'")
spark.sql(f"CREATE VOLUME IF NOT EXISTS mlops_dbx_talk_dev.{username}.helpers")

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
w.workspace.mkdirs(f"/Shared/mlops_talk_{username}")

# %%
dbutils.fs.mkdirs(f"/Volumes/mlops_dbx_talk_dev/{username}/helpers/pyspark_ml_models/")
dbutils.fs.mkdirs(f"/Volumes/mlops_dbx_talk_dev/{username}/helpers/pysparkml/")
