# %%
import mlflow
from mlflow.client import MlflowClient

# %%
mlflow.set_registry_uri("databricks-uc")
client = MlflowClient()

# %%
origin_model_uri = "models:/mlops_dbx_talk_dev.ezapata.telco_churn_model@champion"
destination_model = "mlops_dbx_talk_staging.ezapata.telco_churn_model"

# %%
client.copy_model_version(
    origin_model_uri,
    destination_model
)
